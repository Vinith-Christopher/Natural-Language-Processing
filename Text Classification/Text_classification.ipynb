# %%
# Text classification 

# Import Required Packages  
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import pandas as pd
import matplotlib.pyplot as plt

# %%
# load the dataset from the folder
data = pd.read_json("D:\\NLP\\archive\\Sarcasm_Headlines_Dataset.json", lines=True)
data.head(10)
# Out:
#                                         article_link  \
# 0  https://www.huffingtonpost.com/entry/versace-b...
# 1  https://www.huffingtonpost.com/entry/roseanne-...
# 2  https://local.theonion.com/mom-starting-to-fea...
# 3  https://politics.theonion.com/boehner-just-wan...
# 4  https://www.huffingtonpost.com/entry/jk-rowlin...
# 5  https://www.huffingtonpost.com/entry/advancing...
# 6  https://www.huffingtonpost.com/entry/how-meat-...
# 7  https://www.huffingtonpost.com/entry/boxed-col...
# 8  https://politics.theonion.com/top-snake-handle...
# 9  https://www.huffingtonpost.com/entry/fridays-m...
#
#                                             headline  is_sarcastic
# 0  former versace store clerk sues over secret 'b...             0
# 1  the 'roseanne' revival catches up to our thorn...             0
# 2  mom starting to fear son's web series closest ...             1
# 3  boehner just wants wife to listen, not come up...             1
# 4  j.k. rowling wishes snape happy birthday in th...             0
# 5                        advancing the world's women             0
# 6     the fascinating case for eating lab-grown meat             0
# 7  this ceo will send your kids to school, if you...             0
# 8  top snake handler leaves sinking huckabee camp...             1
# 9  friday's morning email: inside trump's presser...             0

# %%
# Extract the columns of dataframe for classification purpose
contents = np.array(data['headline'])
lab = np.array(data['is_sarcastic'])

# splitting the data for training and testing purpose
# 80% for training and 20% for testing
percent = 0.8
NUM = int(percent * len(contents))

train_sen, test_sen = contents[:NUM], contents[NUM:]
train_lab, test_lab = lab[:NUM], lab[NUM:]

# %%
##define the parameters for the tokenizing and padding
vocab_size = 10000
embedding_dim = 32
max_length = 100
trunc_type='post'  # truncation purpose
oov_tok = "<OOV>" # out of vocabulary token

# %%
tokenizer = Tokenizer(num_words = vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(train_sen)
word_index = tokenizer.word_index

##training sequences and labels
train_seqs = tokenizer.texts_to_sequences(train_sen)
train_padded = pad_sequences(train_seqs, maxlen=max_length, truncating=trunc_type)

##testing sequences and labels
test_seqs = tokenizer.texts_to_sequences(test_sen)
test_padded = pad_sequences(test_seqs,maxlen=max_length)

# %%
# Here is our sequential model with embedding layer, GlobalAveragePooling layer, and two dense alyers


model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

##compile the model with loss function, optimizer and metrics
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 100, 32)           320000
#
#  global_average_pooling1d (G  (None, 32)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 64)                2112
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 322,177
# Trainable params: 322,177
# Non-trainable params: 0
# _________________________________________________________________

# %%
Epochs = 100
##train the model with training and validation set
history = model.fit(
    train_padded,   #training sequence
    train_lab, # training labels
    epochs=Epochs, 
    validation_data=(test_padded, test_lab) # test data
    )
# save the model
model.save('trained_model.h5') # save the model
# Out:
# Epoch 1/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.6006 - accuracy: 0.6591 - val_loss: 0.4112 - val_accuracy: 0.8323
# Epoch 2/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.3335 - accuracy: 0.8608 - val_loss: 0.3596 - val_accuracy: 0.8465
# Epoch 3/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.2574 - accuracy: 0.8983 - val_loss: 0.3574 - val_accuracy: 0.8516
# Epoch 4/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.2151 - accuracy: 0.9145 - val_loss: 0.3616 - val_accuracy: 0.8521
# Epoch 5/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.1814 - accuracy: 0.9298 - val_loss: 0.3743 - val_accuracy: 0.8514
# Epoch 6/100
# 668/668 [==============================] - 5s 8ms/step - loss: 0.1594 - accuracy: 0.9402 - val_loss: 0.4069 - val_accuracy: 0.8422
# Epoch 7/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.1383 - accuracy: 0.9492 - val_loss: 0.4294 - val_accuracy: 0.8474
# Epoch 8/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.1244 - accuracy: 0.9555 - val_loss: 0.4622 - val_accuracy: 0.8414
# Epoch 9/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.1095 - accuracy: 0.9605 - val_loss: 0.4886 - val_accuracy: 0.8426
# Epoch 10/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0984 - accuracy: 0.9654 - val_loss: 0.5369 - val_accuracy: 0.8364
# Epoch 11/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0889 - accuracy: 0.9691 - val_loss: 0.5877 - val_accuracy: 0.8259
# Epoch 12/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0805 - accuracy: 0.9719 - val_loss: 0.5991 - val_accuracy: 0.8330
# Epoch 13/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0739 - accuracy: 0.9748 - val_loss: 0.6697 - val_accuracy: 0.8231
# Epoch 14/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0674 - accuracy: 0.9770 - val_loss: 0.6755 - val_accuracy: 0.8255
# Epoch 15/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0632 - accuracy: 0.9797 - val_loss: 0.7392 - val_accuracy: 0.8151
# Epoch 16/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0578 - accuracy: 0.9803 - val_loss: 0.7616 - val_accuracy: 0.8205
# Epoch 17/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0525 - accuracy: 0.9829 - val_loss: 0.8201 - val_accuracy: 0.8141
# Epoch 18/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0462 - accuracy: 0.9848 - val_loss: 0.9057 - val_accuracy: 0.8076
# Epoch 19/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0464 - accuracy: 0.9840 - val_loss: 0.8998 - val_accuracy: 0.8145
# Epoch 20/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0406 - accuracy: 0.9876 - val_loss: 0.9622 - val_accuracy: 0.8096
# Epoch 21/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0397 - accuracy: 0.9859 - val_loss: 1.0162 - val_accuracy: 0.8038
# Epoch 22/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0364 - accuracy: 0.9875 - val_loss: 1.0240 - val_accuracy: 0.8107
# Epoch 23/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0329 - accuracy: 0.9893 - val_loss: 1.0896 - val_accuracy: 0.8109
# Epoch 24/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0297 - accuracy: 0.9906 - val_loss: 1.1244 - val_accuracy: 0.8092
# Epoch 25/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0292 - accuracy: 0.9904 - val_loss: 1.1715 - val_accuracy: 0.8066
# Epoch 26/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0273 - accuracy: 0.9910 - val_loss: 1.2035 - val_accuracy: 0.8079
# Epoch 27/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0265 - accuracy: 0.9916 - val_loss: 1.2619 - val_accuracy: 0.8033
# Epoch 28/100
# 668/668 [==============================] - 4s 5ms/step - loss: 0.0248 - accuracy: 0.9923 - val_loss: 1.3199 - val_accuracy: 0.8055
# Epoch 29/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0236 - accuracy: 0.9926 - val_loss: 1.4355 - val_accuracy: 0.8025
# Epoch 30/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0222 - accuracy: 0.9923 - val_loss: 1.4307 - val_accuracy: 0.8008
# Epoch 31/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 1.5385 - val_accuracy: 0.8033
# Epoch 32/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0216 - accuracy: 0.9920 - val_loss: 1.5532 - val_accuracy: 0.8010
# Epoch 33/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 1.6221 - val_accuracy: 0.7995
# Epoch 34/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 1.6392 - val_accuracy: 0.8006
# Epoch 35/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0182 - accuracy: 0.9930 - val_loss: 1.6485 - val_accuracy: 0.8018
# Epoch 36/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0174 - accuracy: 0.9938 - val_loss: 1.6945 - val_accuracy: 0.8014
# Epoch 37/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0148 - accuracy: 0.9946 - val_loss: 1.7316 - val_accuracy: 0.7988
# Epoch 38/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0182 - accuracy: 0.9936 - val_loss: 1.7637 - val_accuracy: 0.8012
# Epoch 39/100
# 668/668 [==============================] - 4s 5ms/step - loss: 0.0147 - accuracy: 0.9948 - val_loss: 1.7658 - val_accuracy: 0.7995
# Epoch 40/100
# 668/668 [==============================] - 4s 5ms/step - loss: 0.0109 - accuracy: 0.9963 - val_loss: 1.8504 - val_accuracy: 0.7971
# Epoch 41/100
# 668/668 [==============================] - 4s 5ms/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 1.9340 - val_accuracy: 0.7986
# Epoch 42/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0132 - accuracy: 0.9954 - val_loss: 2.0038 - val_accuracy: 0.7963
# Epoch 43/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0172 - accuracy: 0.9938 - val_loss: 1.9580 - val_accuracy: 0.7997
# Epoch 44/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 1.9810 - val_accuracy: 0.7963
# Epoch 45/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0122 - accuracy: 0.9962 - val_loss: 1.9531 - val_accuracy: 0.7995
# Epoch 46/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0087 - accuracy: 0.9970 - val_loss: 2.0383 - val_accuracy: 0.7990
# Epoch 47/100
# 668/668 [==============================] - 4s 5ms/step - loss: 0.0107 - accuracy: 0.9961 - val_loss: 2.1385 - val_accuracy: 0.7937
# Epoch 48/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 2.1989 - val_accuracy: 0.7952
# Epoch 49/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 2.2822 - val_accuracy: 0.7879
# Epoch 50/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 2.3037 - val_accuracy: 0.7950
# Epoch 51/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0128 - accuracy: 0.9954 - val_loss: 2.3062 - val_accuracy: 0.7950
# Epoch 52/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0109 - accuracy: 0.9956 - val_loss: 2.2580 - val_accuracy: 0.7958
# Epoch 53/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0121 - accuracy: 0.9956 - val_loss: 2.2133 - val_accuracy: 0.7954
# Epoch 54/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0086 - accuracy: 0.9971 - val_loss: 2.3255 - val_accuracy: 0.7961
# Epoch 55/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0117 - accuracy: 0.9957 - val_loss: 2.2762 - val_accuracy: 0.7924
# Epoch 56/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 2.4233 - val_accuracy: 0.7933
# Epoch 57/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0090 - accuracy: 0.9966 - val_loss: 2.4744 - val_accuracy: 0.7926
# Epoch 58/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 2.4677 - val_accuracy: 0.7931
# Epoch 59/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 2.5227 - val_accuracy: 0.7905
# Epoch 60/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 2.4736 - val_accuracy: 0.7937
# Epoch 61/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0088 - accuracy: 0.9971 - val_loss: 2.4673 - val_accuracy: 0.7924
# Epoch 62/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0081 - accuracy: 0.9971 - val_loss: 2.6265 - val_accuracy: 0.7952
# Epoch 63/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0104 - accuracy: 0.9960 - val_loss: 2.5404 - val_accuracy: 0.7954
# Epoch 64/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0071 - accuracy: 0.9975 - val_loss: 2.5866 - val_accuracy: 0.7939
# Epoch 65/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 2.5731 - val_accuracy: 0.7926
# Epoch 66/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0062 - accuracy: 0.9979 - val_loss: 2.6624 - val_accuracy: 0.7946
# Epoch 67/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0075 - accuracy: 0.9973 - val_loss: 2.5734 - val_accuracy: 0.7917
# Epoch 68/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0139 - accuracy: 0.9952 - val_loss: 2.4054 - val_accuracy: 0.7943
# Epoch 69/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 2.5375 - val_accuracy: 0.7905
# Epoch 70/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 2.7871 - val_accuracy: 0.7930
# Epoch 71/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 2.6151 - val_accuracy: 0.7937
# Epoch 72/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0100 - accuracy: 0.9966 - val_loss: 2.4753 - val_accuracy: 0.7911
# Epoch 73/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 2.8331 - val_accuracy: 0.7909
# Epoch 74/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0060 - accuracy: 0.9979 - val_loss: 2.7789 - val_accuracy: 0.7915
# Epoch 75/100
# 668/668 [==============================] - 5s 8ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 2.9421 - val_accuracy: 0.7754
# Epoch 76/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 2.8804 - val_accuracy: 0.7941
# Epoch 77/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 2.7598 - val_accuracy: 0.7913
# Epoch 78/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0062 - accuracy: 0.9974 - val_loss: 2.7781 - val_accuracy: 0.7888
# Epoch 79/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0095 - accuracy: 0.9964 - val_loss: 2.7000 - val_accuracy: 0.7892
# Epoch 80/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0054 - accuracy: 0.9980 - val_loss: 3.0574 - val_accuracy: 0.7858
# Epoch 81/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0060 - accuracy: 0.9973 - val_loss: 2.9454 - val_accuracy: 0.7864
# Epoch 82/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0048 - accuracy: 0.9982 - val_loss: 2.9984 - val_accuracy: 0.7858
# Epoch 83/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 3.2047 - val_accuracy: 0.7931
# Epoch 84/100
# 668/668 [==============================] - 5s 7ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 3.2008 - val_accuracy: 0.7903
# Epoch 85/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 3.2501 - val_accuracy: 0.7920
# Epoch 86/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 3.3065 - val_accuracy: 0.7894
# Epoch 87/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0044 - accuracy: 0.9983 - val_loss: 3.3489 - val_accuracy: 0.7922
# Epoch 88/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0056 - accuracy: 0.9976 - val_loss: 3.2360 - val_accuracy: 0.7894
# Epoch 89/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 3.2021 - val_accuracy: 0.7853
# Epoch 90/100
# 668/668 [==============================] - 4s 7ms/step - loss: 0.0044 - accuracy: 0.9984 - val_loss: 3.4030 - val_accuracy: 0.7911
# Epoch 91/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0082 - accuracy: 0.9971 - val_loss: 3.2136 - val_accuracy: 0.7900
# Epoch 92/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 3.4808 - val_accuracy: 0.7767
# Epoch 93/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 3.1830 - val_accuracy: 0.7885
# Epoch 94/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0048 - accuracy: 0.9984 - val_loss: 3.6005 - val_accuracy: 0.7877
# Epoch 95/100
# 668/668 [==============================] - 4s 5ms/step - loss: 0.0040 - accuracy: 0.9987 - val_loss: 3.6355 - val_accuracy: 0.7888
# Epoch 96/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 3.3962 - val_accuracy: 0.7900
# Epoch 97/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0083 - accuracy: 0.9971 - val_loss: 3.4061 - val_accuracy: 0.7907
# Epoch 98/100
# 668/668 [==============================] - 4s 6ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 3.5064 - val_accuracy: 0.7896
# Epoch 99/100
# 668/668 [==============================] - 4s 5ms/step - loss: 0.0031 - accuracy: 0.9990 - val_loss: 3.5021 - val_accuracy: 0.7890
# Epoch 100/100
# 668/668 [==============================] - 4s 5ms/step - loss: 0.0031 - accuracy: 0.9988 - val_loss: 3.6374 - val_accuracy: 0.7862

# %%
##plot the scores from history
def plot_metrics(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric])
  plt.legend([metric, 'val_'+metric])
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.show()
  
##plot accuracy
plot_metrics(history, "accuracy")

##plot loss
plot_metrics(history, "loss")

# %%
new_sen = ["top snake handler leaves sinking huckabee campaign"]
sequences = tokenizer.texts_to_sequences(new_sen)
padded_seqs = pad_sequences(sequences, maxlen=max_length, truncating=trunc_type)
##print the classification score
x = model.predict(padded_seqs)
# Out:
# 1/1 [==============================] - 0s 112ms/step
